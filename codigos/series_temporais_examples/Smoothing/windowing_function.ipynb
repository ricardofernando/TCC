# %%
### Windowing Function

import pandas as pd
import numpy as np

df = pd.read_csv('istambul_stock_exchange.txt', parse_dates=['date'])

df
# Out:
#           date  TL BASED ISE  USD BASED ISE        SP       DAX      FTSE  \
# 0   2009-01-05      0.035754       0.038376 -0.004679  0.002193  0.003894
# 1   2009-01-06      0.025426       0.031813  0.007787  0.008455  0.012866
# 2   2009-01-07     -0.028862      -0.026353 -0.030469 -0.017833 -0.028735
# 3   2009-01-08     -0.062208      -0.084716  0.003391 -0.011726 -0.000466
# 4   2009-01-09      0.009860       0.009658 -0.021533 -0.019873 -0.012710
# ..         ...           ...            ...       ...       ...       ...
# 531 2011-02-16      0.008599       0.013400  0.006238  0.001925  0.007952
# 532 2011-02-17      0.009310       0.015977  0.003071 -0.001186  0.000345
# 533 2011-02-18      0.000191      -0.001653  0.001923  0.002872 -0.000723
# 534 2011-02-21     -0.013069      -0.013706 -0.020742 -0.014239 -0.011275
# 535 2011-02-22     -0.007246      -0.019442  0.000000 -0.000473 -0.002997
#
#        NIKKEI   BOVESPA        EU        EM
# ...

# %%
import numpy as np
import numpy_ext as npext


def coef_func(x,y):
    coef = np.polyfit(x,y,1)
    return coef[0]

df['fit'] = npext.rolling_apply(coef_func, 4, df.SP.values, df.DAX.values)

df
# Out:
#           date  TL BASED ISE  USD BASED ISE        SP       DAX      FTSE  \
# 0   2009-01-05      0.035754       0.038376 -0.004679  0.002193  0.003894
# 1   2009-01-06      0.025426       0.031813  0.007787  0.008455  0.012866
# 2   2009-01-07     -0.028862      -0.026353 -0.030469 -0.017833 -0.028735
# 3   2009-01-08     -0.062208      -0.084716  0.003391 -0.011726 -0.000466
# 4   2009-01-09      0.009860       0.009658 -0.021533 -0.019873 -0.012710
# ..         ...           ...            ...       ...       ...       ...
# 531 2011-02-16      0.008599       0.013400  0.006238  0.001925  0.007952
# 532 2011-02-17      0.009310       0.015977  0.003071 -0.001186  0.000345
# 533 2011-02-18      0.000191      -0.001653  0.001923  0.002872 -0.000723
# 534 2011-02-21     -0.013069      -0.013706 -0.020742 -0.014239 -0.011275
# 535 2011-02-22     -0.007246      -0.019442  0.000000 -0.000473 -0.002997
#
#        NIKKEI   BOVESPA        EU        EM       fit
# ...

# %%
#Rolling Window - Média
df['SP_mean'] = df['SP'].rolling(window=4).mean()
# Out:
#           date  TL BASED ISE  USD BASED ISE        SP       DAX      FTSE  \
# 0   2009-01-05      0.035754       0.038376 -0.004679  0.002193  0.003894
# 1   2009-01-06      0.025426       0.031813  0.007787  0.008455  0.012866
# 2   2009-01-07     -0.028862      -0.026353 -0.030469 -0.017833 -0.028735
# 3   2009-01-08     -0.062208      -0.084716  0.003391 -0.011726 -0.000466
# 4   2009-01-09      0.009860       0.009658 -0.021533 -0.019873 -0.012710
# ..         ...           ...            ...       ...       ...       ...
# 531 2011-02-16      0.008599       0.013400  0.006238  0.001925  0.007952
# 532 2011-02-17      0.009310       0.015977  0.003071 -0.001186  0.000345
# 533 2011-02-18      0.000191      -0.001653  0.001923  0.002872 -0.000723
# 534 2011-02-21     -0.013069      -0.013706 -0.020742 -0.014239 -0.011275
# 535 2011-02-22     -0.007246      -0.019442  0.000000 -0.000473 -0.002997
#
#        NIKKEI   BOVESPA        EU        EM       fit   SP_mean
# ...
